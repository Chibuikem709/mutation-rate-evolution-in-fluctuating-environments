% %% [markdown]
% # Kimura Simulation and Analysis

% %% [markdown]
% ### Experiment 1

% %%
load('Kimuras sim exp 1.mat')

% %%
env
% Out:
% env =
%
%      1     1

% %%
g1
g2
% Out:
% g1 =
%
%      0     0
%
%
% g2 =
%
%      1     1

% %%
openfig('Kimuras sim exp 1.fig')
% Out:
% ans =
%
%   Figure (1) with properties:
%
%       Number: 1
%         Name: ''
%        Color: [0.9400 0.9400 0.9400]
%     Position: [31 -29 1434 820]
%        Units: 'pixels'
%
%   Use GET to show all properties

% %%
stats
% Out:
% stats =
%
%     'Predict P_fix'     '0.18942'
%     'Observed P_fix'    '0.3132'

% %% [markdown]
% ## Analysis of Experiment 1

% %%
Predicted_Num_Fixed = 0.18942*num_reps
% Out:
% Predicted_Num_Fixed =
%
%    1.8942e+03

% %%
Predicted_Num_Not_Fixed = num_reps - Predicted_Num_Fixed
% Out:
% Predicted_Num_Not_Fixed =
%
%    8.1058e+03

% %%
Observed_Num_Fixed = 0.3132*num_reps
% Out:
% Observed_Num_Fixed =
%
%         3132

% %%
Observed_Num_Not_Fixed = num_reps - Obsereved_Num_Fixed
% Out:
% Observed_Num_Not_Fixed =
%
%         6868

% %%
Obs=[Observed_Num_Fixed Observed_Num_Not_Fixed]
Pred = [Predicted_Num_Fixed Predicted_Num_Not_Fixed]
% Out:
% Obs =
%
%         3132        6868
%
%
% Pred =
%
%    1.0e+03 *
%
%     1.8942    8.1058

% %%
chi2stat = sum((Obs-Pred).^2./Pred)
% Out:
% chi2stat =
%
%   997.8821

% %%
p = 1 - chi2cdf(chi2stat,1)
% Out:
% p =
%
%      0

% %% [markdown]
% On the website: http://graphpad.com/quickcalcs/contingency1.cfm, the values above were recalcuted and yeilded:

% %%
exp1 = imread('Experiment1.png');

% %%
image(exp1)
