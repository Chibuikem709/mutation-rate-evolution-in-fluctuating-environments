% %% [markdown]
% # Kimura Simulation and Analysis

% %% [markdown]
% ## Experiment 5

% %%
load('Kimuras sim exp 5.mat')

% %%
env
% Out:
% env =
%
%      0     1

% %%
g1
g2
% Out:
% g1 =
%
%      1     0
%
%
% g2 =
%
%      0     1

% %%
openfig('Kimuras sim exp 5.fig')
% Out:
% ans =
%
%   Figure (1) with properties:
%
%       Number: 1
%         Name: ''
%        Color: [0.9400 0.9400 0.9400]
%     Position: [31 -29 1434 820]
%        Units: 'pixels'
%
%   Use GET to show all properties

% %%
stats
% Out:
% stats =
%
%     'Predict P_fix'     '0.19926'
%     'Observed P_fix'    '0.3272'

% %% [markdown]
% ## Analysis of Experiment 5

% %%
Predicted_Num_Fixed = 0.19926*num_reps
% Out:
% Predicted_Num_Fixed =
%
%    1.9926e+03

% %%
Predicted_Num_Not_Fixed = num_reps - Predicted_Num_Fixed
% Out:
% Predicted_Num_Not_Fixed =
%
%    8.0074e+03

% %%
Observed_Num_Fixed = 0.3272*num_reps
% Out:
% Observed_Num_Fixed =
%
%         3272

% %%
Observed_Num_Not_Fixed = num_reps - Observed_Num_Fixed
% Out:
% Observed_Num_Not_Fixed =
%
%         6728

% %%
Obs=[Observed_Num_Fixed Observed_Num_Not_Fixed]
Pred = [Predicted_Num_Fixed Predicted_Num_Not_Fixed]
% Out:
% Obs =
%
%         3272        6728
%
%
% Pred =
%
%    1.0e+03 *
%
%     1.9926    8.0074

% %%
chi2stat = sum((Obs-Pred).^2./Pred)
% Out:
% chi2stat =
%
%    1.0259e+03

% %%
p = 1 - chi2cdf(chi2stat,1)
% Out:
% p =
%
%      0

% %% [markdown]
% On the website: http://graphpad.com/quickcalcs/contingency1.cfm, the values above were recalcuted and yeilded:

% %%
exp5 = imread('Experiment5.png');
image(exp5)
