% %% [markdown]
% # Kimura Simulation and Analysis

% %% [markdown]
% ## Experiment 3

% %%
load('Kimuras sim exp 3.mat')

% %%
env
% Out:
% env =
%
%      1     1

% %%
g1
g2
% Out:
% g1 =
%
%      1     1
%
%
% g2 =
%
%      1     1

% %%
openfig('Kimuras sim exp 3.fig')
% Out:
% ans =
%
%   Figure (1) with properties:
%
%       Number: 1
%         Name: ''
%        Color: [0.9400 0.9400 0.9400]
%     Position: [31 -29 1434 820]
%        Units: 'pixels'
%
%   Use GET to show all properties

% %%
stats
% Out:
% stats =
%
%     'Predict P_fix'     'NaN'
%     'Observed P_fix'    '1'

% %% [markdown]
% ## Analysis of Experiment 3

% %% [markdown]
% No analysis is available for Experiment 3 (12/08/15)
